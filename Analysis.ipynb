# %% [markdown]
# # Análisis

# %% [markdown]
# ## Parámetros

# %%
nombre_proyecto = "TFM"
nombre_entrenamiento = "prueba"
parametros = [nombre_proyecto, nombre_entrenamiento]

# %% [markdown]
# ## Figura 1: Comparación de modelos

# %%
#figure_1.py, figure_1_d_auc_prc.py, figure_1_e_confusion_matrix.py
# %run analysis/figure_1/figure_1.py parametros
# Out:
# sorted_dict OrderedDict([('RBF Support Vector Machine ', 0.9973055065647656), ('Logistic Regression', 0.9973055065647658), ('P-NET', 0.9999999999999998)])
# 0 RBF Support Vector Machine
# 1 Logistic Regression
# 2 P-NET
# [[ 6  9]
#  [ 0 27]]
# Normalized confusion matrix
# [[ 40.  60.]
#  [  0. 100.]]
# D:\Universidad\UGR\TFM\codigo\python3\analysis\figure_1\figure_1.py:145: MatplotlibDeprecationWarning: Passing the fontdict parameter of _set_ticklabels() positionally is deprecated since Matplotlib 3.3; the parameter will become keyword-only two minor releases later.
#   ax.set_xticklabels(classes, fontproperties)
# D:\Universidad\UGR\TFM\codigo\python3\analysis\figure_1\figure_1.py:147: MatplotlibDeprecationWarning: Passing the fontdict parameter of _set_ticklabels() positionally is deprecated since Matplotlib 3.3; the parameter will become keyword-only two minor releases later.
#   ax.set_yticklabels(classes, fontproperties, rotation=90)

# %% [markdown]
# ## Figura 2: Análisis de la red

# %%
#%run analysis/prepare_data2.py
#%run analysis/figure_3/figure_3_sankey.py

# %run analysis/figure_3/figure3_b_gene_importance.py
# Out:
#             response
# GSM1594221         0
# GSM1594225         0
# GSM1594250         0
# GSM1594377         1
# GSM1594438         1
# [2, 1, 4, 5, 3, 6]
#              value
# variable
# IRF3      0.062732
# CENPL     0.051312
# PIK3CD    0.050113
# PRKACA    0.037355
# B2M       0.032316
# IKBKE     0.030578
# NLRX1     0.026110
# SHC1      0.022963
# NUDC      0.022190
# MAVS      0.021546
# 1 MAVS
# 2 NUDC
# 3 SHC1
# 4 NLRX1
# 5 IKBKE
# 6 B2M
# 7 PRKACA
# 8 PIK3CD
# 9 CENPL
# 10 IRF3
# D:\Universidad\UGR\TFM\codigo\python3\analysis\figure_3\figure3_b_gene_importance.py:309: MatplotlibDeprecationWarning:
#
# Passing the minor parameter of set_ticks() positionally is deprecated since Matplotlib 3.2; the parameter will become keyword-only two minor releases later.
#
# D:\Universidad\UGR\TFM\codigo\python3\analysis\figure_3\figure3_b_gene_importance.py:310: MatplotlibDeprecationWarning:
#
# ...
